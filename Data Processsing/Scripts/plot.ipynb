# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(r'../Data/data_72038.csv')
data = data.set_index('Time')
data
# Out:
#        IMU_SHIN_L_YAW  IMU_SHIN_L_PITCH  IMU_SHIN_L_ROLL  IMU_SHIN_R_YAW  \
# Time
# 1.88             0.00              0.23            -4.57           -0.01
# 1.88             0.00              0.23            -4.57           -0.01
# 1.88             0.00              0.24            -4.57           -0.01
# 1.90            -0.02              0.30            -4.56            0.59
# 1.91            -0.02              0.30            -4.56            0.59
# ...               ...               ...              ...             ...
# 10.20            4.58              0.16            -4.50            6.68
# 10.21            4.58              0.16            -4.50            6.68
# 10.22            4.58              0.16            -4.50            6.68
# 10.23            4.58              0.17            -4.50            6.68
# NaN               NaN               NaN              NaN             NaN
#
#        IMU_SHIN_R_PITCH  IMU_SHIN_R_ROLL  Unnamed: 7
# Time
# ...

# %%
plt.figure(figsize=(10,10))
for col in data:
    plt.plot(data.index, data[col])
plt.show()
