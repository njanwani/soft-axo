# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(r'../Data/data.csv')
data = data.set_index('Time')
data
# Out:
#            IMU_SHIN_L_YAW  IMU_SHIN_L_PITCH  IMU_SHIN_L_ROLL  IMU_SHIN_R_YAW  \
# Time
# 3.844000            -0.01              0.05            -4.56            0.01
# 3.849000            -0.01              0.05            -4.56            0.01
# 3.859000            -0.01              0.05            -4.56            0.01
# 3.872000            -0.01              0.06            -4.61            0.01
# 3.878000            -0.01              0.07            -4.61            0.01
# ...                   ...               ...              ...             ...
# 21.010000           14.31              0.26            -4.91            0.01
# 21.020000           14.31              0.26            -4.91            0.01
# 21.030001           14.31              0.27            -4.91            0.01
# 21.040001           14.31              0.27            -4.91            0.01
# 21.049999           14.31              0.26            -4.91            0.01
#
#            IMU_SHIN_R_PITCH  IMU_SHIN_R_ROLL  Unnamed: 7
# Time
# 3.844000              -0.47            -2.13         NaN
# 3.849000              -0.47            -2.13         NaN
# 3.859000              -0.47            -2.15         NaN
# 3.872000              -0.47            -2.15         NaN
# 3.878000              -0.47            -2.15         NaN
# ...                     ...              ...         ...
# 21.010000             -0.51            -2.23         NaN
# 21.020000             -0.51            -2.23         NaN
# 21.030001             -0.51            -2.23         NaN
# 21.040001             -0.51            -2.23         NaN
# 21.049999             -0.51            -2.23         NaN
#
# [1719 rows x 7 columns]

# %%
for col in data:
    if '_L_' in col:
        plt.plot(data.index, data[col])
