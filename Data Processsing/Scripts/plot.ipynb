# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv(r'../Data/data_full.csv')
data = data.set_index('Time')
data
# Out:
#        IMU_SHIN_L_YAW  IMU_SHIN_L_PITCH  IMU_SHIN_L_ROLL  IMU_SHIN_R_YAW  \
# Time
# 5.61             0.00             -0.27            -2.51           -0.01
# 5.61             0.00             -0.27            -2.51           -0.01
# 5.63             0.00             -0.27            -2.55           -0.01
# 5.64             0.00             -0.27            -2.55           -0.02
# 5.65             0.00             -0.27            -2.55           -0.02
# ...               ...               ...              ...             ...
# 43.75           -3.65             -0.58            -2.74           -3.62
# 43.76           -3.65             -0.58            -2.74           -3.62
# 43.77           -3.65             -0.58            -2.74           -3.62
# 43.78           -3.65             -0.58            -2.74           -3.62
# 43.79           -3.65             -0.58            -2.74           -3.62
#
#        IMU_SHIN_R_PITCH  IMU_SHIN_R_ROLL  FSR_HEEL_L_RAW  FSR_HEEL_R_RAW  \
# Time
# ...

# %%
plt.figure(figsize=(10,10))
for col in data:
    if 'FSR' not in col:
        plt.plot(data[col])
plt.show()
